# %%
import os, argparse
import pickle
import cv2, numpy as np
#from keras.models import model_from_json
from tensorflow.keras.optimizers import SGD
from sklearn.externals import joblib
from tensorflow.keras import backend as K
#import keras
from tensorflow.keras.models import load_model
from sklearn.cluster import KMeans
from matplotlib import pyplot as plt

# %%
infile = open(r'feature_vectors_denis_samples.pkl','rb')
new_dict = pickle.load(infile)
infile.close()

# %%
X=new_dict

# %%
X=compressed

# %%
#testing clustering feature vectors, not ideal
kmeans = KMeans(n_clusters=20, init='k-means++', max_iter=300, n_init=10, random_state=0)
pred_y = kmeans.fit_predict(X)
plt.scatter(X[:,0], X[:,1])
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s=300, c='red')
plt.show()

# %%
pred_y[30]
# Out:
# 9

# %%
type(pred_y)
# Out:
# numpy.ndarray

# %%
import os
PATH=os.getcwd()
#data_path = PATH + '/every_aerin'
data_path=r"C:\Users\dedunn\Desktop\every_aerin"
#"C:\Users\dedunn\Desktop\every_aerin"
data_dir_list = os.listdir(data_path)

# %% [markdown]
# # Create meta date for projector

# %%
LOG_DIR = PATH+ '\embedding-logs'
#metadata = os.path.join(LOG_DIR, 'metadata2.tsv')

#%%
#data_path = PATH + '/data'
data_dir_list = os.listdir(data_path)

# %%
metadata_file = open(os.path.join(LOG_DIR, 'metadata_test_classes.tsv'), 'w')
metadata_file.write('Class\tName\n')

# %%
import csv

# %%
data=str(pred_y)

# %%
with open('metadata_test3_classes.tsv', 'w', newline='') as f_output:
    tsv_output = csv.writer(f_output, delimiter='\t')
    tsv_output.writerow(data1)

# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\dedunn\Desktop\metadata_test3_classes.tsv")
# Out:
# Empty DataFrame
# ...

# %%
names=[]

# %%
data1=list(pred_y)

# %%
df=pd.DataFrame(data1)

# %%
df.to_csv('denis_100p_20c.tsv',header=None,index=False)

# %%
df[1:]
# Out:
#       0
# 1    11
# 2     1
# 3     1
# 4     1
# 5     1
# ..   ..
# 915  23
# 916  19
# 917   1
# 918   1
# 919  23
#
# [919 rows x 1 columns]

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=100, svd_solver='randomized', whiten=True)
pca.fit(X)
compressed = pca.transform(X)

# %%
df1=pd.DataFrame(list(compressed))

# %%
df1.to_csv('denis_100_pca.tsv',header=None,index=False)
