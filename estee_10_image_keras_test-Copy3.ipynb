# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D 
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K

# %%
import tensorflow
layers = tensorflow.keras.layers
BatchNormalization = tensorflow.keras.layers.BatchNormalization
Conv2D = tensorflow.keras.layers.Conv2D
Flatten = tensorflow.keras.layers.Flatten
TensorBoard = tensorflow.keras.callbacks.TensorBoard
ModelCheckpoint = tensorflow.keras.callbacks.ModelCheckpoint

# %%
tensorflow.VERSION
# Out:
# '1.15.0'

# %%
from time import time
from tensorflow.keras import optimizers
from tensorflow.keras import layers
from tensorflow.keras.models import load_model
from tensorflow.keras import models

from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.applications.vgg16 import decode_predictions
from tensorflow.keras.applications.vgg16 import VGG16
# load an image from file
import sys
from numpy import load
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from matplotlib.image import imread
from numpy import expand_dims

import pickle
from tensorflow.keras.preprocessing.image import array_to_img

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from numpy import expand_dims
import numpy as np
import os

# %%
#import tensorflow as tf
from PIL import Image
from keras.callbacks import TensorBoard
from time import time
Image.MAX_IMAGE_PIXELS = None

# %%
import keras
from keras.layers import LeakyReLU
from keras.layers import Conv2D
from keras.callbacks import ModelCheckpoint
from keras.callbacks import EarlyStopping

# %%
#from tensorflow.keras.models import Sequential
#tensorflow.enable_eager_execution()
from PIL import Image
Image.MAX_IMAGE_PIXELS = None

# %%
from keras import optimizers
from keras import layers

# %%
from keras.models import load_model
from keras import models

from keras.applications.vgg16 import preprocess_input

# %%
# Example of creating a CNN model with many VGG blocks
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.utils import plot_model
from keras.utils import to_categorical
# function for creating a vgg block
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16
# load an image from file
import sys
from numpy import load
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from matplotlib.image import imread
from numpy import expand_dims

import pickle
from keras.preprocessing.image import array_to_img

from keras.preprocessing.image import ImageDataGenerator

from numpy import expand_dims
import numpy as np
import os

# %%
tf.version

# %%
datagen = ImageDataGenerator(
    #featurewise_center=True,
    #featurewise_std_normalization=True,
    preprocessing_function=preprocess_input,
    #rescale=1/255,
    rotation_range=30,
    width_shift_range=2,
    height_shift_range=2,
    brightness_range=(.7,1.3),
    shear_range=0.8,
    zoom_range=[.6,1.8],
    channel_shift_range=.7,
    fill_mode="nearest",
    horizontal_flip=True)

# %%
# define a new model with random weights and 10 classes
new_input = Input(shape=(224, 224, 3))
model = VGG16( weights='imagenet',input_shape=new_input, classes=44,include_top=False)
keras.layers.Dense(64, activation='relu'),
keras.layers.Dense(44, activation='softmax'),
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
es=EarlyStopping(patience=5, monitor='loss',verbose=1)

model.fit(X, y, epochs=1000,callbacks=[es],validation_split=.1)

test_loss, test_acc = model.evaluate(X, y)
print('Test accuracy:', test_acc)

# %%
model = keras.Sequential([
keras.layers.Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"),
keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"),
keras.layers.ELU(alpha=1.0)
keras.layers.MaxPooling2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPooling2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPooling2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPooling2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPooling2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Flatten(),
keras.layers.Dense(4096,activation="relu"),
keras.layers.Dense(4096,activation="relu"),
keras.layers.Dense(44, activation="softmax"),
])


model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
es=EarlyStopping(patience=3, monitor='loss',verbose=1)

model.fit(X, y, epochs=500,callbacks=[es],batch_size=32,validation_split=.1)

test_loss, test_acc = model.evaluate(X, y)
print('Test accuracy:', test_acc)

# %%
IMG_SIZE=224

# %%
#model.compile(loss='categorical_crossentropy',optimizer = 'adam',metrics=['accuracy'])
#model.fit(X,y,epochs=10,validation_split=.1)

# %%
# fit the data augmentation
train_datagen.fit(x_train)

# setup generator
train_generator = train_datagen.flow_from_directory(
        directory='/Users/denisdunn/Desktop/'+'full_aerin',
        target_size=(IMG_SIZE, IMG_SIZE),
        color_mode='rgb',
        batch_size=1,
        class_mode='categorical')

# train model
model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples,
    epochs=epochs,
    validation_data=validation_generator, # optional - if used needs to be defined
    validation_steps=nb_validation_samples)

# %%
model=load_model(r"C:\Users\dedunn\Downloads\weights-improvement-92-0.70.hdf5")
# Out:
# WARNING:tensorflow:From C:\Users\dedunn\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
from tensorflow.keras.applications.vgg16 import VGG16
model=VGG16(include_top=False, weights='imagenet',input_shape=(224,224,3))

# %%
from keras.applications import resnet50
resnet50 = resnet50.ResNet50(include_top=True, weights='imagenet')
#model.load_weights('resnet50_weights_tf_dim_ordering_tf_kernels.h5')
#model.compile(optimizer='rmsprop', loss='categorical_crossentropy')

# %%
VGG16.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = models.Sequential()
#25088
model.add(VGG16)

# %%
model.build()

# %%
model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
for i, layer in enumerate(model.layers):
    print(i,layer.name,layer.trainable)
# Out:
# 0 input_2 True
# 1 block1_conv1 True
# 2 block1_conv2 True
# 3 block1_pool True
# 4 block2_conv1 True
# 5 block2_conv2 True
# 6 block2_pool True
# 7 block3_conv1 True
# 8 block3_conv2 True
# 9 block3_conv3 True
# 10 block3_pool True
# 11 block4_conv1 True
# 12 block4_conv2 True
# 13 block4_conv3 True
# 14 block4_pool True
# 15 block5_conv1 True
# 16 block5_conv2 True
# 17 block5_conv3 True
# 18 block5_pool True

# %%
#model.add(keras.layers.Flatten()),
#model.add(keras.layers.Dense(4086, activation='elu')),
tensorflow.keras.model.add(tensorflow.keras.layers.Dense(528, activation='elu')),
#model.add(layers.Dense(128, activation='elu')),     
#model.add(layers.Dense(43, activation='softmax'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-176327481a09> in <module>
#       1 #model.add(keras.layers.Flatten()),
#       2 #model.add(keras.layers.Dense(4086, activation='elu')),
# ----> 3 tensorflow.keras.model.add(tensorflow.keras.layers.Dense(528, activation='elu')),
#       4 #model.add(layers.Dense(128, activation='elu')),
#       5 #model.add(layers.Dense(43, activation='softmax'))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow_core\python\util\module_wrapper.py in __getattr__(self, name)
#     191   def __getattr__(self, name):
#     192     try:
# --> 193       attr = getattr(self._tfmw_wrapped_module, name)
#     194     except AttributeError:
#     195       if not self._tfmw_public_apis:
#
# AttributeError: module 'tensorflow.python.keras.api._v1.keras' has no attribute 'model'

# %%
model.add(layers.Dense(44, activation='softmax'))

# %%
#model = models.Sequential()
#25088
#build(VGG16)
#model.add(VGG16)
#model = model_2.Sequential()
#model = keras.Sequential()
for layer in model.layers:
    layer.trainable = False   # go through until last layer
    #layer.name = layer.name + str("_2")
    #model.add(layer)
#model.add(keras.layers.Flatten()),
#model.add(keras.layers.Dense(4086, activation='elu')),
#model.add(layers.Dense(528, activation='elu')),
#model.add(layers.Dense(128, activation='elu')),     
#model.add(layers.Dense(44, activation='softmax')) 

# Add the vgg convolutional base model
# Add new layers

#model.add(layers.Flatten(input_shape=(20,20,1)))

#model.add(layers.Dense(1024, activation='relu'))

#model.add(layers.Dropout(0.5))

# %%
model.build()

# %%
import pkg_resources

for entry_point in pkg_resources.iter_entry_points('tensorboard_plugins'):
    print(entry_point.dist)

# %%
model.summary()

# %%
saver.save(session, LOG_DIR/model.ckpt, step)

# %%
tensorboard = tensorflow.keras.callbacks.TensorBoard(log_dir='/Users/denisdunn/Desktop/logs/{}'.format(time()),histogram_freq=1)

# %%
#run in separate terminal before training
#tensorboard --logdir=/Users/denisdunn/Desktop/logs/
sgd= optimizers.SGD(lr=.0001,)
model.compile(optimizer=sgd,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
filepath="weights-improvement-{epoch:02d}-{accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='accuracy', verbose=1, save_best_only=True, mode='max')
#callbacks_list = [checkpoint]
#es=EarlyStopping(patience=15, monitor='loss',verbose=1)
#datagen.fit(X)
train_generator = datagen.flow_from_directory(
        directory='/Users/denisdunn/Desktop/'+'full_aerin',
        target_size=(IMG_SIZE, IMG_SIZE),
        color_mode='rgb',
        batch_size=1,
        class_mode='categorical')

model.fit_generator(train_generator,
    steps_per_epoch=20,
    epochs=1000,callbacks=[checkpoint,tensorboard])

# %%
model = keras.Sequential([
    #keras.layers.Conv2D(input_shape=(50,50,1),filters=64,kernel_size=(1,1), activation='relu',strides=(1,1),padding='valid'),
    #keras.layers.BatchNormalization(axis=-1,momentum=.99,epsilon=.001,center=True,scale=True,beta_initializer='zeros',gamma_initializer='ones',moving_mean_initializer='zero',moving_variance_initializer='ones'),
    #keras.layers.Conv2D(filters=256,kernel_size=(5,5), strides=(3,3),padding='valid', activation='elu'),
    #keras.layers.BatchNormalization(axis=-1),#momentum=.99,epsilon=.001,center=True,scale=True,beta_initializer='zeros',gamma_initializer='ones',moving_mean_initializer='zero',moving_variance_initializer='ones'),
    #keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(1,1), padding='valid'),
    keras.layers.Flatten(input_shape=(20,20,1)),
    #keras.layers.Dense(4096),
    #keras.layers.ELU(alpha=1.0),
    keras.layers.Dense(528, activation='elu'),
    #keras.layers.BatchNormalization(axis=-1),#momentum=.99,epsilon=.001,center=True,scale=True,beta_initializer='zeros',gamma_initializer='ones',moving_mean_initializer='zero',moving_variance_initializer='ones'),
    keras.layers.Dense(528, activation='elu'),
    #keras.layers.Dropout(.3),
    keras.layers.Dense(128, activation='elu'),
    #keras.layers.Dropout(.5),
    keras.layers.Dense(64, activation='elu'),
    keras.layers.Dense(44, activation='softmax'),
])
sgd= optimizers.SGD(lr=.1,decay=1e-1, momentum=.9,nesterov=True)
model.compile(optimizer="SGD",
              loss='categorical_crossentropy',
              metrics=['accuracy'])
filepath="weights-improvement-{epoch:02d}-{accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='accuracy', verbose=1, save_best_only=True, mode='max')
#callbacks_list = [checkpoint]
#es=EarlyStopping(patience=15, monitor='loss',verbose=1)
#datagen.fit(X)
train_generator = datagen.flow_from_directory(
        directory='/Users/denisdunn/Desktop/'+'full_aerin',
        target_size=(IMG_SIZE, IMG_SIZE),
        color_mode='grayscale',
        batch_size=1,
        class_mode='categorical')

model.fit_generator(train_generator,
    steps_per_epoch=2000,
    epochs=1000,callbacks=[checkpoint]) 
#model.fit_generator(datagen.flow(X,y,batch_size=4),
     #steps_per_epoch=(len(X)//4),callbacks=[checkpoint],
    #epochs=30000)
#model.fit(X, y, epochs=500, batch_size=32,callbacks=[es],validation_split=.1)

test_loss, test_acc = model.evaluate(X, y)
print('Test accuracy:', test_acc)

# %%
# fit the data augmentation
train_datagen.fit(x_train)

# setup generator
train_generator = train_datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_height, img_width),
        batch_size=batch_size,
        class_mode='categorical')

# train model
model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples,
    epochs=epochs,
    validation_data=validation_generator, # optional - if used needs to be defined
    validation_steps=nb_validation_samples)

# %%
model.save('128_filters_100_color_2conv_max_batch2.h5')

# %%
train_generator.class_indices
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-8b783e645587> in <module>
# ----> 1 train_generator.class_indices
#
# NameError: name 'train_generator' is not defined

# %%
test=os.listdir(r"C:\Users\dedunn\Desktop\full_aerin")

# %%
from keras.models import load_model

# %%
model=load_model(r"C:\Users\dedunn\Desktop\weights-improvement-33-0.85.hdf5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-4b86faa8a47d> in <module>
# ----> 1 model=load_model(r"C:\Users\dedunn\Desktop\weights-improvement-33-0.85.hdf5")
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\engine\saving.py in load_model(filepath, custom_objects, compile)
#     417     f = h5dict(filepath, 'r')
#     418     try:
# --> 419         model = _deserialize_model(f, custom_objects, compile)
#     420     finally:
#     421         if opened_new_file:
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\engine\saving.py in _deserialize_model(f, custom_objects, compile)
#     223         raise ValueError('No model found in config.')
#     224     model_config = json.loads(model_config.decode('utf-8'))
# --> 225     model = model_from_config(model_config, custom_objects=custom_objects)
#     226     model_weights_group = f['model_weights']
#     227
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\engine\saving.py in model_from_config(config, custom_objects)
#     456                         '`Sequential.from_config(config)`?')
#     457     from ..layers import deserialize
# --> 458     return deserialize(config, custom_objects=custom_objects)
#     459
#     460
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\layers\__init__.py in deserialize(config, custom_objects)
#      53                                     module_objects=globs,
#      54                                     custom_objects=custom_objects,
# ---> 55                                     printable_module_name='layer')
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\utils\generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     143                     config['config'],
#     144                     custom_objects=dict(list(_GLOBAL_CUSTOM_OBJECTS.items()) +
# --> 145                                         list(custom_objects.items())))
#     146             with CustomObjectScope(custom_objects):
#     147                 return cls.from_config(config['config'])
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\engine\sequential.py in from_config(cls, config, custom_objects)
#     298         for conf in layer_configs:
#     299             layer = layer_module.deserialize(conf,
# --> 300                                              custom_objects=custom_objects)
#     301             model.add(layer)
#     302         if not model.inputs and build_input_shape:
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\layers\__init__.py in deserialize(config, custom_objects)
#      53                                     module_objects=globs,
#      54                                     custom_objects=custom_objects,
# ---> 55                                     printable_module_name='layer')
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\utils\generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     145                                         list(custom_objects.items())))
#     146             with CustomObjectScope(custom_objects):
# --> 147                 return cls.from_config(config['config'])
#     148         else:
#     149             # Then `cls` may be a function returning a class.
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\engine\base_layer.py in from_config(cls, config)
#    1107             A layer instance.
#    1108         """
# -> 1109         return cls(**config)
#    1110
#    1111     def count_params(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name + '` call to the ' +
#      90                               'Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\layers\convolutional.py in __init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     488             kernel_constraint=kernel_constraint,
#     489             bias_constraint=bias_constraint,
# --> 490             **kwargs)
#     491
#     492     def get_config(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\layers\convolutional.py in __init__(self, rank, filters, kernel_size, strides, padding, data_format, dilation_rate, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     115         self.activation = activations.get(activation)
#     116         self.use_bias = use_bias
# --> 117         self.kernel_initializer = initializers.get(kernel_initializer)
#     118         self.bias_initializer = initializers.get(bias_initializer)
#     119         self.kernel_regularizer = regularizers.get(kernel_regularizer)
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\initializers.py in get(identifier)
#     506 def get(identifier):
#     507     if isinstance(identifier, dict):
# --> 508         return deserialize(identifier)
#     509     elif isinstance(identifier, six.string_types):
#     510         config = {'class_name': str(identifier), 'config': {}}
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\initializers.py in deserialize(config, custom_objects)
#     501                                     module_objects=globals(),
#     502                                     custom_objects=custom_objects,
# --> 503                                     printable_module_name='initializer')
#     504
#     505
#
# ~\AppData\Local\Continuum\anaconda3\envs\tensorflow_env\lib\site-packages\keras\utils\generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     136             if cls is None:
#     137                 raise ValueError('Unknown ' + printable_module_name +
# --> 138                                  ': ' + class_name)
#     139         if hasattr(cls, 'from_config'):
#     140             custom_objects = custom_objects or {}
#
# ValueError: Unknown initializer: GlorotUniform

# %%
preprocess('/Users/denisdunn/Desktop/aerin_test/Screen Shot 2020-02-11 at 12.30.00 PM.png', 28, 28)

# %%
from keras.preprocessing import image

# %%
img_path=r"C:\Users\dedunn\Desktop\full_aerin\F19_AERIN_BCRF_SILO.tif\_0_9599.png"

# %%
img = image.load_img(img_path, target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

features = model.predict(x)

# %%
np.argmax(features,axis=1)
# Out:
# array([[[ 0,  0,  2, ...,  0,  0,  0],
#         [ 0,  0,  2, ...,  0,  0,  0],
#         [ 0,  0,  2, ...,  0,  0,  0],
#         ...,
#         [ 0,  0, 79, ...,  0,  0,  0],
#         [ 0,  0, 79, ...,  0,  0,  0],
#         [ 0,  0,  2, ...,  0,  0,  0]]], dtype=int64)

# %%
result=model.predict_classes(x)
print(test[int(result)])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-142f9472fe6e> in <module>
#       1 result=model.predict_classes(x)
# ----> 2 print(test[int(result)])
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
IMG_SIZE=15

# %%
def image_processing(test):
    #array_test=img_to_array(test)
    #img_array=cv2.imread(test)
    array_resize=cv2.resize(test,(IMG_SIZE,IMG_SIZE))
    test_image = array_resize[...,::-1]
    return (np.array(test_image).reshape(1,IMG_SIZE,IMG_SIZE,3))/255

# %%
img_array = cv2.imread('/Users/denisdunn/Desktop/F19_AERIN_LIM_DIGITAL_1_R300.tif')#,cv2.IMREAD_GRAYSCALE)
                
new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
test_image = new_array[...,::-1]

# %%
denis=cv2.imread('/Users/denisdunn/Desktop/191001_LSF_SHOT24_6612_2480DI_i_ADOBERGB.jpg',cv2.IMREAD_GRAYSCALE)
#cv2.IMREAD_GRAYSCALE

# %%
new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                test_image = new_array[...,::-1]

# %%
answer=image_processing(denis)

# %%
model.predict_classes(x)

# %%
pic='/Users/denisdunn/Desktop/HOL19_AERIN_ MODEL_F72.tif'

# %%
def pic_test(pic):
    denis=cv2.imread(pic)#,cv2.IMREAD_GRAYSCALE)
    answer=image_processing(denis)
    result=model.predict_classes(answer)
    direct='/Users/denisdunn/Desktop/full_aerin/{}/{}'.format(CATEGORIES[int(result)],CATEGORIES[int(result)])
    return load_img(direct)

# %%
direct='/Users/denisdunn/Desktop/full_aerin/{}/{}'.format(CATEGORIES[int(result)],CATEGORIES[int(result)])

# %%
pic_test('/Users/denisdunn/Desktop/_0_117.png')

# %%
model.save('feb_5_size_25_batch5_model.h5')

# %%
model.predict(answer)

# %%
np.save('/Users/denisdunn/Desktop/DATADIR/X',X)
np.save('/Users/denisdunn/Desktop/DATADIR/y',y)

# %%
model = keras.Sequential([
keras.layers.Conv2D(input_shape=(32,32,1),filters=64,kernel_size=(3,3),padding="same", activation="relu"),
keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"),
keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Flatten(),
keras.layers.Dense(units=4096,activation="relu"),
keras.layers.Dense(units=4096,activation="relu"),
keras.layers.Dense(units=44, activation="softmax")])

# %%
X.shape

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
es=EarlyStopping(patience=20, monitor='acc',verbose=1)
model.fit(X, y, epochs=1000, batch_size=10,callbacks=[es])

test_loss, test_acc = model.evaluate(X, y)
print('Test accuracy:', test_acc)

# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import io
import itertools
from packaging import version
from six.moves import range

import tensorflow as tf
from tensorflow import keras

import matplotlib.pyplot as plt
import numpy as np
import sklearn.metrics

print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >= 2, \
    "This notebook requires TensorFlow 2.0 or above."

# %%
import cv2,time
import numpy as np
print(cv2.__version__)
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
/anaconda3/lib/python3.7/site-packages/cv2/data/haarcascade_frontalface_default.xml

# %%
face_cascade=cv2.CascadeClassifier('/anaconda3/lib/python3.7/site-packages/cv2/data/haarcascade_frontalface_default.xml')

# %%
face_cascade=cv2.CascadeClassifier('file:///Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/cv2/data/haarcascade_frontalface_default.xml')

# %%
face_cascade

# %%
gray=cv2.imread('/Users/denisdunn/Desktop/Ivb19_0881-319x319.png')

# %%
faces=face_cascade.detectMultiScale(gray,scaleFactor=1.05,minNeighbors=5)

# %%
print(faces)

# %%
for x,y,w,h, in faces:
    img = cv2.rectangle(gray, (x,y), (x+w,y+h),(0,255,0),3)

# %%
cv2.imshow('gray',img)

# %%
#import cv2

#cvim2disp = cv2.imread('/Users/denisdunn/Desktop/Ivb19_0881-319x319.png')
cv2.imshow('img', img)
while(True):
    k = cv2.waitKey(33)
    if k == -1:  # if no key was pressed, -1 is returned
        continue
    else:
        break
cv2.destroyWindow('img')

# %%
video=cv2.VideoCapture(0)
check,frame=video.read()
time.sleep(3) 
cv2.imshow('Capture',frame)
cv2.waitKey(0)
video.release()

# %%
pwd

# %%
cv2.destroyWindow('gray')

# %%
filename = '/Users/denisdunn/Desktop/shirt_test.png'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]

cv2.imshow('dst',img)
while(True):
    k = cv2.waitKey(33)
    if k == -1:  # if no key was pressed, -1 is returned
        continue
    else:
        break
cv2.destroyWindow('img')
#if cv2.waitKey(0) & 0xff == 27:
    #cv2.destroyAllWindows()

# %%
filename = '/Users/denisdunn/Desktop/shirt_test.png'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]

cv2.imshow('dst',img)
cv2.waitKey()

cv2.destroyAllWindows()

# %%
from tensorflow.keras.models import Sequential

# %%
import keras

# %%
cv2.destroyAllWindows()

# %%
img = cv2.imread("image.jpg")
cv2.startWindowThread()
cv2.namedWindow("preview")
cv2.imshow("preview", im

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
from keras.preprocessing.image import save_img

# %%
img = load_img('/Users/denisdunn/Desktop/full_aerin/Aerin_Office_PhotoFrame_8x10.tif/Aerin_Office_PhotoFrame_8x10.tif')

# %%
img_array = img_to_array(img)

# %%
save_img('office_photoframe.jpg', img_array)

# %%
pwd
