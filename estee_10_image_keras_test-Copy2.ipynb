# %%
# import the necessary packages
from keras.models import Sequential
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D 
from keras.layers.core import Activation
from keras.layers.core import Flatten
from keras.layers.core import Dropout
from keras.layers.core import Dense
from keras import backend as K
# Out:
# Using TensorFlow backend.

# %%
import tensorflow
from PIL import Image

Image.MAX_IMAGE_PIXELS = None

# %%
from tensorflow.keras.models import Sequential

# %%
# Example of creating a CNN model with many VGG blocks
from keras.models import Model
from keras.layers import Input
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.utils import plot_model
from keras.utils import to_categorical
# function for creating a vgg block
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16
# load an image from file
import sys
from numpy import load
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from matplotlib.image import imread
from numpy import expand_dims

import pickle
from keras.preprocessing.image import array_to_img

from keras.preprocessing.image import ImageDataGenerator

from numpy import expand_dims
import numpy as np
import os

# %%
/Users/denisdunn/Desktop/full_aerin/fifty_plus_class

# %%
import os
directory=os.listdir("/Users/denisdunn/Desktop/full_aerin")

# %%
file=('/Users/denisdunn/Desktop/full_aerin/fifty_plus_class/{}').format(directory[0])

# %%
directory
# Out:
# ['F19_AERIN_LIM_DIGITAL_1_HORIZ.jpg',
#  'F19_AERIN_AM_DIGITAL_5_SQUARE.jpg',
#  'AERIN_IM_MOODBOARD_LR.jpg',
#  'F19_AERIN_HOL_DIGITAL_HORIZ_10.jpg',
#  'F19_AERIN_LIM_100ML_SILO_1.tif',
#  '.DS_Store',
#  'F19_AERIN_HOL_DIGITAL_SQUARE_2_v2.jpg',
#  '191001_LSF_SHOT23_5967_2480DI_F_ADOBERGB.jpg',
#  'S20_AERIN_WG_DIGITAL_SQUARE_09.jpg',
#  'HOL18_AERIN_HOLIDAY_MODEL.tif',
#  'AERIN_TV_MOODBOARD_LR.jpg',
#  'AERIN_MH_MOODBOARD_LR.jpg',
#  'FL17_AERIN_TLJ_TLS_MODEL_DPS_HR.tif',
#  'Aerin_Office_PhotoFrame_8x10.tif',
#  'SP19_Aerin_Aegea_Blossom_Model_Loose_REL_72dpi.jpg',
#  'AERIN_WS_MOODBOARD_LR.jpg',
#  'SP17_AERIN_DOR_HERO_1.jpg',
#  'F19_AERIN_LIM_MODEL_F72.tif',
#  'F19_AERIN_AM_DIGITAL_2_SQUARE.jpg',
#  'F19_AERIN_HOL_DIGITAL_SQUARE_1_v2.jpg',
#  'F19_AERIN_LIM_BC_SILO.tif',
#  'AERIN_LP_MOODBOARD_LR.jpg',
#  'F19_AERIN_LIM_DIGITAL_4_VERT.jpg',
#  'F19_AERIN_LIM_DIGITAL_6.tif',
#  'AERIN_GR_MOODBOARD_LR.jpg',
#  'F19_AERIN_BCRF_SILO.tif',
#  'S20_AERIN_WG_DIGITAL_SQUARE_10.jpg',
#  'F19_AERIN_NOAM_SET.tif',
#  'F19_AERIN_LIM_MODEL_SQUARE.jpg',
#  'S19_AERIN_AB_DIGITAL_5_F600.tif',
#  'S20_AERIN_WG_DIGITAL_SQUARE_11.jpg',
#  'FL17_AERIN_TLJ_TLS_HERO.jpg',
#  'F19_AERIN_HOL_DIGITAL_HORIZ_9.jpg',
#  'S17_AERIN_ROSE_COL_MODEL_DPS_72dpi.jpg',
#  'AERIN_AM_MOODBOARD_LR.jpg',
#  'F19_AERIN_AM_DIGITAL_3_SQUARE.jpg',
#  'AERIN_IJ_MOODBOARD_LR.jpg',
#  'S20_AERIN_WG_DIGITAL_SQUARE_02.jpg',
#  'F19_AERIN_AM_DIGITAL_4_SQUARE_v3.jpg',
#  'F19_AERIN_EDV_MODEL_EMEA_R72.tif',
#  'S20_AERIN_WG_DIGITAL_SQUARE_01.jpg',
#  'S20_AERIN_WG_DIGITAL_HZTL_13.jpg',
#  'S19_AERIN_AB_RB_SILO_1.jpg',
#  'S20_AERIN_WG_DIGITAL_HZTL_12.jpg',
#  'AERIN_ER_MOODBOARD_LR.jpg']

# %%
direct=('/Users/denisdunn/Desktop/full_aerin/{}').format(directory[1])

# %%
import shutil
#newPath = shutil.move(file, direct)

# %%
#os.makedirs(direct)

# %%
#for files in directory:
   # direct=('/Users/denisdunn/Desktop/full_aerin/{}').format(files)
    #os.makedirs(direct)
    #file=('/Users/denisdunn/Desktop/full_aerin/fifty_plus_class/{}').format(files)
    #shutil.move(file, direct)

# %%
directory.remove('.DS_Store')

# %%
directory
# Out:
# ['F19_AERIN_LIM_DIGITAL_1_HORIZ.jpg',
#  'F19_AERIN_AM_DIGITAL_5_SQUARE.jpg',
#  'AERIN_IM_MOODBOARD_LR.jpg',
#  'F19_AERIN_HOL_DIGITAL_HORIZ_10.jpg',
#  'F19_AERIN_LIM_100ML_SILO_1.tif',
#  'F19_AERIN_HOL_DIGITAL_SQUARE_2_v2.jpg',
#  '191001_LSF_SHOT23_5967_2480DI_F_ADOBERGB.jpg',
#  'S20_AERIN_WG_DIGITAL_SQUARE_09.jpg',
#  'HOL18_AERIN_HOLIDAY_MODEL.tif',
#  'AERIN_TV_MOODBOARD_LR.jpg',
#  'AERIN_MH_MOODBOARD_LR.jpg',
#  'FL17_AERIN_TLJ_TLS_MODEL_DPS_HR.tif',
#  'Aerin_Office_PhotoFrame_8x10.tif',
#  'SP19_Aerin_Aegea_Blossom_Model_Loose_REL_72dpi.jpg',
#  'AERIN_WS_MOODBOARD_LR.jpg',
#  'SP17_AERIN_DOR_HERO_1.jpg',
#  'F19_AERIN_LIM_MODEL_F72.tif',
#  'F19_AERIN_AM_DIGITAL_2_SQUARE.jpg',
#  'F19_AERIN_HOL_DIGITAL_SQUARE_1_v2.jpg',
#  'F19_AERIN_LIM_BC_SILO.tif',
#  'AERIN_LP_MOODBOARD_LR.jpg',
#  'F19_AERIN_LIM_DIGITAL_4_VERT.jpg',
#  'F19_AERIN_LIM_DIGITAL_6.tif',
#  'AERIN_GR_MOODBOARD_LR.jpg',
#  'F19_AERIN_BCRF_SILO.tif',
#  'S20_AERIN_WG_DIGITAL_SQUARE_10.jpg',
#  'F19_AERIN_NOAM_SET.tif',
#  'F19_AERIN_LIM_MODEL_SQUARE.jpg',
#  'S19_AERIN_AB_DIGITAL_5_F600.tif',
#  'S20_AERIN_WG_DIGITAL_SQUARE_11.jpg',
#  'FL17_AERIN_TLJ_TLS_HERO.jpg',
#  'F19_AERIN_HOL_DIGITAL_HORIZ_9.jpg',
#  'S17_AERIN_ROSE_COL_MODEL_DPS_72dpi.jpg',
#  'AERIN_AM_MOODBOARD_LR.jpg',
#  'F19_AERIN_AM_DIGITAL_3_SQUARE.jpg',
#  'AERIN_IJ_MOODBOARD_LR.jpg',
#  'S20_AERIN_WG_DIGITAL_SQUARE_02.jpg',
#  'F19_AERIN_AM_DIGITAL_4_SQUARE_v3.jpg',
#  'F19_AERIN_EDV_MODEL_EMEA_R72.tif',
#  'S20_AERIN_WG_DIGITAL_SQUARE_01.jpg',
#  'S20_AERIN_WG_DIGITAL_HZTL_13.jpg',
#  'S19_AERIN_AB_RB_SILO_1.jpg',
#  'S20_AERIN_WG_DIGITAL_HZTL_12.jpg',
#  'AERIN_ER_MOODBOARD_LR.jpg']

# %%
data=load_img(test)

# %%
/Users/denisdunn/Desktop/full_aerin/AERIN_IM_MOODBOARD_LR.jpg/AERIN_IM_MOODBOARD_LR.jpg

# %%
for picture in directory:
    try:
        pic=('/Users/denisdunn/Desktop/full_aerin/{}/{}').format(picture,picture)
        data=load_img(pic)
        samples = expand_dims(data, 0)
        saved=('/Users/denisdunn/Desktop/full_aerin/{}').format(picture)
        it = datagen.flow(samples,batch_size=1,save_to_dir=saved)
        for i in range(30):
            batch = it.next()
    except:
        pass

# %%
picture
# Out:
# 'S19_AERIN_AB_DIGITAL_5_F600.tif'

# %%
data=('/Users/denisdunn/Desktop/full_aerin/{}/{}').format('picture','picture')

# %%
data=load_img('/Users/denisdunn/Desktop/full_aerin/F19_AERIN_LIM_DIGITAL_1_HORIZ.jpg/F19_AERIN_LIM_DIGITAL_1_HORIZ.jpg')

# %%
samples = expand_dims(data, 0)

# %%
datagen = ImageDataGenerator(
    #featurewise_center=True,
    #featurewise_std_normalization=True,
    #rotation_range=5,
    #width_shift_range=10,
    #height_shift_range=10,
    #brightness_range=(.95,1.2),
    #channel_shift_range=20.0,
    horizontal_flip=True)

# %%
it = datagen.flow(samples,batch_size=1,save_to_dir='/Users/denisdunn/Desktop/full_aerin/F19_AERIN_LIM_DIGITAL_1_HORIZ.jpg')
#it = datagen.flow(samples,batch_size=1)

# %%
# generate samples and plot
for i in range(20):
  # define subplot
    #plt.subplot(330 + 1 + i)
  # generate batch of images
    batch = it.next()
# convert to unsigned integers for viewing 
    #image = batch[0].astype('uint32')
    
# plot raw pixel data 
    #plt.imshow(image)
# show the figure
#plt.show()

# %%
array_to_img(image)

# %%
import glob
print(glob.glob("/Users/denisdunn/Desktop/full_aerin/*.jpg"))
# Out:
# ['/Users/denisdunn/Desktop/full_aerin/F19_AERIN_LIM_DIGITAL_1_HORIZ.jpg', '/Users/denisdunn/Desktop/full_aerin/F19_AERIN_AM_DIGITAL_5_SQUARE.jpg', '/Users/denisdunn/Desktop/full_aerin/AERIN_IM_MOODBOARD_LR.jpg', '/Users/denisdunn/Desktop/full_aerin/F19_AERIN_HOL_DIGITAL_HORIZ_10.jpg', '/Users/denisdunn/Desktop/full_aerin/F19_AERIN_HOL_DIGITAL_SQUARE_2_v2.jpg', '/Users/denisdunn/Desktop/full_aerin/191001_LSF_SHOT23_5967_2480DI_F_ADOBERGB.jpg', '/Users/denisdunn/Desktop/full_aerin/S20_AERIN_WG_DIGITAL_SQUARE_09.jpg', '/Users/denisdunn/Desktop/full_aerin/AERIN_TV_MOODBOARD_LR.jpg', '/Users/denisdunn/Desktop/full_aerin/AERIN_MH_MOODBOARD_LR.jpg', '/Users/denisdunn/Desktop/full_aerin/SP19_Aerin_Aegea_Blossom_Model_Loose_REL_72dpi.jpg', '/Users/denisdunn/Desktop/full_aerin/AERIN_WS_MOODBOARD_LR.jpg', '/Users/denisdunn/Desktop/full_aerin/SP17_AERIN_DOR_HERO_1.jpg', '/Users/denisdunn/Desktop/full_aerin/F19_AERIN_AM_DIGITAL_2_SQUARE.jpg', '/Users/denisdunn/Desktop/full_aerin/F19_AERIN_HOL_DIGITAL_SQUARE_1_v2.jpg', '/Users/denisdunn/Desktop/full_aerin/AERIN_LP_MOODBOARD_LR.jpg', '/Users/denisdunn/Desktop/full_aerin/F19_AERIN_LIM_DIGITAL_4_VERT.jpg', '/Users/denisdunn/Desktop/full_aerin/AERIN_GR_MOODBOARD_LR.jpg', '/Users/denisdunn/Desktop/full_aerin/S20_AERIN_WG_DIGITAL_SQUARE_10.jpg', '/Users/denisdunn/Desktop/full_aerin/F19_AERIN_LIM_MODEL_SQUARE.jpg', '/Users/denisdunn/Desktop/full_aerin/S20_AERIN_WG_DIGITAL_SQUARE_11.jpg', '/Users/denisdunn/Desktop/full_aerin/FL17_AERIN_TLJ_TLS_HERO.jpg', '/Users/denisdunn/Desktop/full_aerin/F19_AERIN_HOL_DIGITAL_HORIZ_9.jpg', '/Users/denisdunn/Desktop/full_aerin/S17_AERIN_ROSE_COL_MODEL_DPS_72dpi.jpg', '/Users/denisdunn/Desktop/full_aerin/AERIN_AM_MOODBOARD_LR.jpg', '/Users/denisdunn/Desktop/full_aerin/F19_AERIN_AM_DIGITAL_3_SQUARE.jpg', '/Users/denisdunn/Desktop/full_aerin/AERIN_IJ_MOODBOARD_LR.jpg', '/Users/denisdunn/Desktop/full_aerin/S20_AERIN_WG_DIGITAL_SQUARE_02.jpg', '/Users/denisdunn/Desktop/full_aerin/F19_AERIN_AM_DIGITAL_4_SQUARE_v3.jpg', '/Users/denisdunn/Desktop/full_aerin/S20_AERIN_WG_DIGITAL_SQUARE_01.jpg', '/Users/denisdunn/Desktop/full_aerin/S20_AERIN_WG_DIGITAL_HZTL_13.jpg', '/Users/denisdunn/Desktop/full_aerin/S19_AERIN_AB_RB_SILO_1.jpg', '/Users/denisdunn/Desktop/full_aerin/S20_AERIN_WG_DIGITAL_HZTL_12.jpg', '/Users/denisdunn/Desktop/full_aerin/AERIN_ER_MOODBOARD_LR.jpg']

# %%
cat=os.listdir("/Users/denisdunn/Desktop/full_aerin")

# %%
cat.remove('.DS_Store')

# %%
len(cat)
# Out:
# 44

# %%
training_data=[]

# %%
len(training_data)
# Out:
# 0

# %%
IMG_SIZE=224

# %%
DATADIR='/Users/denisdunn/Desktop/full_aerin'
CATEGORIES=cat

# %%
#path =  os.path.join(DATADIR,category)
for category in CATEGORIES:
    path =  os.path.join(DATADIR,category)
    class_num = CATEGORIES.index(category)

# %%
path
# Out:
# '/Users/denisdunn/Desktop/full_aerin/AERIN_ER_MOODBOARD_LR.jpg'

# %%
img_array = cv2.imread('/Users/denisdunn/Desktop/F19_AERIN_LIM_DIGITAL_1_R300.tif')#,cv2.IMREAD_GRAYSCALE)
                
new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
test_image = new_array[...,::-1]

# %%
def create_training_data():
    for category in CATEGORIES:
        path =  os.path.join(DATADIR,category)
        class_num = CATEGORIES.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img))#,cv2.IMREAD_GRAYSCALE)
                
                new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                test_image = new_array[...,::-1]
                training_data.append([test_image,class_num])
            except Exception as e:
                pass
create_training_data()
#cv2.IMREAD_GRAYSCALE

# %%
print(len(training_data))
# Out:
# 2674

# %%
import random
random.shuffle(training_data)

# %%
X = []
y = []

# %%
for features, label in training_data:   
    X.append(features)
    y.append(label)
X=np.array(X).reshape(-1,IMG_SIZE,IMG_SIZE,3)

# %%
from keras.utils import to_categorical
y = to_categorical(y,num_classes=44,dtype='float32')

# %%
X=X/255.0

# %%
y=np.array(y)

# %%
p=cv2.imread('/Users/denisdunn/Desktop/shirt_test.png')

# %%
image = load_img('/Users/denisdunn/Desktop/Screen Shot 2019-12-10 at 1.50.12 PM.png', target_size=(224, 224))

# %%
image = img_to_array(image)

# %%
image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))

# %%
image = preprocess_input(image)

# %%
from keras.callbacks import EarlyStopping

# %%
# define a new model with random weights and 10 classes
new_input = Input(shape=(224, 224, 3))
model = VGG16( weights='imagenet',input_shape=new_input, classes=44,include_top=False)
keras.layers.Dense(64, activation='relu'),
keras.layers.Dense(44, activation='softmax'),
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
es=EarlyStopping(patience=5, monitor='loss',verbose=1)

model.fit(X, y, epochs=1000,callbacks=[es],validation_split=.1)

test_loss, test_acc = model.evaluate(X, y)
print('Test accuracy:', test_acc)
# Out:
# ---------------------------------------------------------------------------
# OperatorNotAllowedInGraphError            Traceback (most recent call last)
# <ipython-input-198-6b70f31d5045> in <module>
#       1 # define a new model with random weights and 10 classes
#       2 new_input = Input(shape=(224, 224, 3))
# ----> 3 model = VGG16( weights='imagenet',input_shape=new_input, classes=44,include_top=False)
#       4 keras.layers.Dense(64, activation='relu'),
#       5 keras.layers.Dense(44, activation='softmax'),
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/applications/__init__.py in wrapper(*args, **kwargs)
#      18         kwargs['models'] = models
#      19         kwargs['utils'] = utils
# ---> 20         return base_fun(*args, **kwargs)
#      21
#      22     return wrapper
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/applications/vgg16.py in VGG16(*args, **kwargs)
#       9 @keras_modules_injection
#      10 def VGG16(*args, **kwargs):
# ---> 11     return vgg16.VGG16(*args, **kwargs)
#      12
#      13
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras_applications/vgg16.py in VGG16(include_top, weights, input_tensor, input_shape, pooling, classes, **kwargs)
#      97                                       data_format=backend.image_data_format(),
#      98                                       require_flatten=include_top,
# ---> 99                                       weights=weights)
#     100
#     101     if input_tensor is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras_applications/imagenet_utils.py in _obtain_input_shape(input_shape, default_size, min_size, data_format, require_flatten, weights)
#     292                                  str(default_shape) + '.')
#     293         return default_shape
# --> 294     if input_shape:
#     295         if data_format == 'channels_first':
#     296             if input_shape is not None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in __bool__(self)
#     755       `TypeError`.
#     756     """
# --> 757     self._disallow_bool_casting()
#     758
#     759   def __nonzero__(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in _disallow_bool_casting(self)
#     524     else:
#     525       # Default: V1-style Graph execution.
# --> 526       self._disallow_in_graph_mode("using a `tf.Tensor` as a Python `bool`")
#     527
#     528   def _disallow_iteration(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py in _disallow_in_graph_mode(self, task)
#     513     raise errors.OperatorNotAllowedInGraphError(
#     514         "{} is not allowed in Graph execution. Use Eager execution or decorate"
# --> 515         " this function with @tf.function.".format(task))
#     516
#     517   def _disallow_bool_casting(self):
#
# OperatorNotAllowedInGraphError: using a `tf.Tensor` as a Python `bool` is not allowed in Graph execution. Use Eager execution or decorate this function with @tf.function.

# %%
model = keras.Sequential([
keras.layers.Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3),padding="same", activation="relu"),
keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"),
keras.layers.ELU(alpha=1.0)
keras.layers.MaxPooling2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPooling2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPooling2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPooling2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPooling2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Flatten(),
keras.layers.Dense(4096,activation="relu"),
keras.layers.Dense(4096,activation="relu"),
keras.layers.Dense(44, activation="softmax"),
])


model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
es=EarlyStopping(patience=3, monitor='loss',verbose=1)

model.fit(X, y, epochs=500,callbacks=[es],batch_size=32,validation_split=.1)

test_loss, test_acc = model.evaluate(X, y)
print('Test accuracy:', test_acc)
# Out:
# Train on 2406 samples, validate on 268 samples
# Epoch 1/500
# 2406/2406 [==============================] - 1151s 478ms/step - loss: 3.7899 - accuracy: 0.0229 - val_loss: 3.7863 - val_accuracy: 0.0037
# Epoch 2/500
# 2406/2406 [==============================] - 1159s 482ms/step - loss: 3.7851 - accuracy: 0.0191 - val_loss: 3.7864 - val_accuracy: 0.0075
# Epoch 3/500
# 2406/2406 [==============================] - 1161s 483ms/step - loss: 3.7849 - accuracy: 0.0200 - val_loss: 3.7878 - val_accuracy: 0.0075
# Epoch 4/500
# 2406/2406 [==============================] - 1140s 474ms/step - loss: 3.7845 - accuracy: 0.0220 - val_loss: 3.7877 - val_accuracy: 0.0037
# Epoch 5/500
# 2406/2406 [==============================] - 1169s 486ms/step - loss: 3.7844 - accuracy: 0.0170 - val_loss: 3.7884 - val_accuracy: 0.0075
# Epoch 6/500
# 2406/2406 [==============================] - 1213s 504ms/step - loss: 3.7842 - accuracy: 0.0245 - val_loss: 3.7893 - val_accuracy: 0.0037
# Epoch 7/500
# 2406/2406 [==============================] - 1130s 470ms/step - loss: 3.7842 - accuracy: 0.0249 - val_loss: 3.7898 - val_accuracy: 0.0037
# Epoch 8/500
# 2406/2406 [==============================] - 1124s 467ms/step - loss: 3.7841 - accuracy: 0.0204 - val_loss: 3.7906 - val_accuracy: 0.0037
# Epoch 9/500
# 2406/2406 [==============================] - 1117s 464ms/step - loss: 3.7842 - accuracy: 0.0249 - val_loss: 3.7910 - val_accuracy: 0.0037
# Epoch 10/500
# 2406/2406 [==============================] - 1125s 468ms/step - loss: 3.7841 - accuracy: 0.0249 - val_loss: 3.7915 - val_accuracy: 0.0037
# Epoch 11/500
# 2406/2406 [==============================] - 1121s 466ms/step - loss: 3.7840 - accuracy: 0.0249 - val_loss: 3.7925 - val_accuracy: 0.0037
# Epoch 12/500
# 1888/2406 [======================>.......] - ETA: 3:51 - loss: 3.7837 - accuracy: 0.0265
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-213-42114ca1aa0a> in <module>
#      30 es=EarlyStopping(patience=3, monitor='loss',verbose=1)
#      31
# ---> 32 model.fit(X, y, epochs=500,callbacks=[es],batch_size=32,validation_split=.1)
#      33
#      34 test_loss, test_acc = model.evaluate(X, y)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
out=model.predict(image)
decode_predictions(out)

# %%
#model.compile(loss='categorical_crossentropy',optimizer = 'adam',metrics=['accuracy'])
#model.fit(X,y,epochs=10,validation_split=.1)

# %%
import keras
from keras.layers import LeakyReLU
from keras.layers import Conv2D

# %%
model = keras.Sequential([
    keras.layers.Conv2D(input_shape=(224,224,3),filters=64,kernel_size=(3,3), strides=(2,2),padding='valid',data_format="channels_last"),
    keras.layers.Conv2D(filters=128,kernel_size=(3,3), strides=(2,2),padding='valid',data_format="channels_last"),
    keras.layers.MaxPooling2D(pool_size=(2, 2), strides=(2,2), padding='valid', data_format="channels_last"),
    keras.layers.Flatten(),
    keras.layers.Dense(4096),
    #keras.layers.ELU(alpha=1.0),
    keras.layers.Dense(4096, activation='elu'),
    keras.layers.Dense(528, activation='elu'),
    keras.layers.Dense(44, activation='softmax'),
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
es=EarlyStopping(patience=5, monitor='loss',verbose=1)

model.fit(X, y, epochs=500, batch_size=32,callbacks=[es],validation_split=.1)

test_loss, test_acc = model.evaluate(X, y)
print('Test accuracy:', test_acc)
# Out:
# Train on 2406 samples, validate on 268 samples
# Epoch 1/500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-217-a9be6d98e683> in <module>
#      16 es=EarlyStopping(patience=5, monitor='loss',verbose=1)
#      17
# ---> 18 model.fit(X, y, epochs=500, batch_size=32,callbacks=[es],validation_split=.1)
#      19
#      20 test_loss, test_acc = model.evaluate(X, y)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
model.save('128_filters_100_color_2conv_max_batch2.h5')

# %%
.2 * 9900
# Out:
# 1980.0

# %%
test=os.listdir("/Users/denisdunn/Desktop/aerin_test")

# %%
from keras.models import load_model

# %%
#model=load_model('/Users/denisdunn/Downloads/feb_14th.h5')

# %%
preprocess('/Users/denisdunn/Desktop/aerin_test/Screen Shot 2020-02-11 at 12.30.00 PM.png', 28, 28)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-221-7206c3b89104> in <module>
# ----> 1 preprocess('/Users/denisdunn/Desktop/aerin_test/Screen Shot 2020-02-11 at 12.30.00 PM.png', 28, 28)
#
# NameError: name 'preprocess' is not defined

# %%
pic='/Users/denisdunn/Desktop/aerin_test/S20_AERIN_WG_DIGITAL_SQUARE_09.jpg'
pic_test(pic)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-220-8ffb008282ab> in <module>
#       1 pic='/Users/denisdunn/Desktop/aerin_test/S20_AERIN_WG_DIGITAL_SQUARE_09.jpg'
# ----> 2 pic_test(pic)
#
# <ipython-input-105-e18508f3f2e6> in pic_test(pic)
#       4     result=model.predict_classes(answer)
#       5     direct='/Users/denisdunn/Desktop/full_aerin/{}/{}'.format(CATEGORIES[int(result)],CATEGORIES[int(result)])
# ----> 6     return load_img(direct)
#       7
#
# ~/opt/anaconda3/lib/python3.7/site-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     108         raise ImportError('Could not import PIL.Image. '
#     109                           'The use of `load_img` requires PIL.')
# --> 110     img = pil_image.open(path)
#     111     if color_mode == 'grayscale':
#     112         if img.mode != 'L':
#
# ~/opt/anaconda3/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode)
#    2764
#    2765     if filename:
# -> 2766         fp = builtins.open(filename, "rb")
#    2767         exclusive_fp = True
#    2768
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/denisdunn/Desktop/full_aerin/F19_AERIN_BCRF_SILO.tif/F19_AERIN_BCRF_SILO.tif'

# %%
load_img(pic)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1080x1080 at 0x143BCBA50>

# %%
IMG_SIZE=15

# %%
def image_processing(test):
    #array_test=img_to_array(test)
    #img_array=cv2.imread(test)
    array_resize=cv2.resize(test,(IMG_SIZE,IMG_SIZE))
    test_image = array_resize[...,::-1]
    return (np.array(test_image).reshape(1,IMG_SIZE,IMG_SIZE,3))/255

# %%
img_array = cv2.imread('/Users/denisdunn/Desktop/F19_AERIN_LIM_DIGITAL_1_R300.tif')#,cv2.IMREAD_GRAYSCALE)
                
new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
test_image = new_array[...,::-1]

# %%
denis=cv2.imread('/Users/denisdunn/Desktop/191001_LSF_SHOT24_6612_2480DI_i_ADOBERGB.jpg',cv2.IMREAD_GRAYSCALE)
#cv2.IMREAD_GRAYSCALE

# %%
new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                test_image = new_array[...,::-1]

# %%
answer=image_processing(denis)

# %%
result=model.predict_classes(answer)
print(CATEGORIES[int(result)])
# Out:
# F19_AERIN_AM_DIGITAL_5_SQUARE.jpg

# %%
pic='/Users/denisdunn/Desktop/HOL19_AERIN_ MODEL_F72.tif'

# %%
def pic_test(pic):
    denis=cv2.imread(pic)#,cv2.IMREAD_GRAYSCALE)
    answer=image_processing(denis)
    result=model.predict_classes(answer)
    direct='/Users/denisdunn/Desktop/full_aerin/{}/{}'.format(CATEGORIES[int(result)],CATEGORIES[int(result)])
    return load_img(direct)

# %%
direct='/Users/denisdunn/Desktop/full_aerin/{}/{}'.format(CATEGORIES[int(result)],CATEGORIES[int(result)])

# %%
pic_test('/Users/denisdunn/Desktop/_0_117.png')
# Out:
# (<PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=5021x3032 at 0x2A6339790>,
#  <PIL.PngImagePlugin.PngImageFile image mode=RGB size=5021x3032 at 0x2A6339C50>)

# %%
model.save('feb_5_size_25_batch5_model.h5')

# %%
model.predict(answer)
# Out:
# array([[4.55650948e-02, 5.05535342e-02, 4.35844883e-02, 4.84597087e-02,
#         4.65853065e-02, 4.71747890e-02, 4.07053865e-02, 1.42613942e-06,
#         2.11655518e-07, 6.76927273e-04, 7.49849388e-03, 7.40330461e-06,
#         4.20434065e-02, 4.42895107e-02, 1.72497313e-02, 0.00000000e+00,
#         5.09360246e-02, 1.29048522e-10, 4.11587954e-03, 4.83092554e-02,
#         2.32230313e-02, 4.57705408e-02, 3.64078500e-04, 2.40401234e-02,
#         4.72728759e-02, 4.40890975e-02, 4.68082950e-02, 4.84615527e-02,
#         1.73832814e-04, 3.55367623e-02, 5.42847702e-05, 1.15570029e-22,
#         5.77951198e-08, 2.51759831e-02, 7.47341489e-15, 2.11998262e-02,
#         9.76294745e-04, 4.64065761e-06, 3.35875328e-08, 4.41359431e-02,
#         1.02462625e-04, 4.75596935e-02, 7.29285087e-03, 1.09689199e-06]],
#       dtype=float32)

# %%
np.save('/Users/denisdunn/Desktop/DATADIR/X',X)
np.save('/Users/denisdunn/Desktop/DATADIR/y',y)

# %%
model = keras.Sequential([
keras.layers.Conv2D(input_shape=(50,50,1),filters=64,kernel_size=(3,3),padding="same", activation="relu"),
keras.layers.Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"),
keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"),
keras.layers.MaxPool2D(pool_size=(2,2),strides=(2,2)),
keras.layers.Flatten(),
keras.layers.Dense(units=4096,activation="relu"),
keras.layers.Dense(units=4096,activation="relu"),
keras.layers.Dense(units=44, activation="softmax")])

# %%
X.shape
# Out:
# (924, 50, 50, 1)

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
es=EarlyStopping(patience=20, monitor='acc',verbose=1)
model.fit(X, y, epochs=1000, batch_size=10,callbacks=[es])

test_loss, test_acc = model.evaluate(X, y)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/1000
# 1363/1363 [==============================] - 103s 76ms/step - loss: 3.8303 - acc: 0.0147
# Epoch 2/1000
# 1363/1363 [==============================] - 106s 78ms/step - loss: 3.7857 - acc: 0.0154
# Epoch 3/1000
# 1363/1363 [==============================] - 98s 72ms/step - loss: 3.7853 - acc: 0.0183
# Epoch 4/1000
# 1363/1363 [==============================] - 105s 77ms/step - loss: 3.7851 - acc: 0.0161
# Epoch 5/1000
# 1363/1363 [==============================] - 106s 78ms/step - loss: 3.7851 - acc: 0.0191
# Epoch 6/1000
# 1363/1363 [==============================] - 212s 156ms/step - loss: 3.7850 - acc: 0.0198
# Epoch 7/1000
# 1363/1363 [==============================] - 95s 70ms/step - loss: 3.7851 - acc: 0.0103
# Epoch 8/1000
# 1363/1363 [==============================] - 805s 591ms/step - loss: 3.7850 - acc: 0.0147
# Epoch 9/1000
# 1363/1363 [==============================] - 96s 71ms/step - loss: 3.7852 - acc: 0.0191
# Epoch 10/1000
# 1363/1363 [==============================] - 282s 207ms/step - loss: 3.7851 - acc: 0.0161
# Epoch 11/1000
# 1363/1363 [==============================] - 103s 76ms/step - loss: 3.7850 - acc: 0.0169
# Epoch 12/1000
# 1363/1363 [==============================] - 98s 72ms/step - loss: 3.7851 - acc: 0.0176
# Epoch 13/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7851 - acc: 0.0169
# Epoch 14/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7850 - acc: 0.0169
# Epoch 15/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7850 - acc: 0.0154
# Epoch 16/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7851 - acc: 0.0176
# Epoch 17/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7852 - acc: 0.0183
# Epoch 18/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7850 - acc: 0.0176
# Epoch 19/1000
# 1363/1363 [==============================] - 96s 71ms/step - loss: 3.7851 - acc: 0.0117
# Epoch 20/1000
# 1363/1363 [==============================] - 102s 75ms/step - loss: 3.7850 - acc: 0.0161
# Epoch 21/1000
# 1363/1363 [==============================] - 104s 76ms/step - loss: 3.7851 - acc: 0.0191
# Epoch 22/1000
# 1363/1363 [==============================] - 99s 73ms/step - loss: 3.7851 - acc: 0.0220
# Epoch 23/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7851 - acc: 0.0191
# Epoch 24/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7850 - acc: 0.0183
# Epoch 25/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7850 - acc: 0.0169
# Epoch 26/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7851 - acc: 0.0147
# Epoch 27/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7850 - acc: 0.0191
# Epoch 28/1000
# 1363/1363 [==============================] - 99s 73ms/step - loss: 3.7850 - acc: 0.0103
# Epoch 29/1000
# 1363/1363 [==============================] - 104s 77ms/step - loss: 3.7850 - acc: 0.0176
# Epoch 30/1000
# 1363/1363 [==============================] - 101s 74ms/step - loss: 3.7851 - acc: 0.0161
# Epoch 31/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7851 - acc: 0.0139
# Epoch 32/1000
# 1363/1363 [==============================] - 96s 71ms/step - loss: 3.7851 - acc: 0.0161
# Epoch 33/1000
# 1363/1363 [==============================] - 96s 70ms/step - loss: 3.7851 - acc: 0.0161
# Epoch 34/1000
# 1363/1363 [==============================] - 95s 70ms/step - loss: 3.7850 - acc: 0.0191
# Epoch 35/1000
# 1363/1363 [==============================] - 96s 71ms/step - loss: 3.7851 - acc: 0.0183
# Epoch 36/1000
# 1363/1363 [==============================] - 104s 76ms/step - loss: 3.7850 - acc: 0.0191
# Epoch 37/1000
# 1363/1363 [==============================] - 99s 73ms/step - loss: 3.7851 - acc: 0.0132
# Epoch 38/1000
# 1363/1363 [==============================] - 95s 70ms/step - loss: 3.7851 - acc: 0.0161
# Epoch 39/1000
#  860/1363 [=================>............] - ETA: 36s - loss: 3.7850 - acc: 0.0151
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-136-21f77caad402>", line 5, in <module>
#     model.fit(X, y, epochs=1000, batch_size=10,callbacks=[es])
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/keras/engine/training.py", line 1039, in fit
#     validation_steps=validation_steps)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/keras/engine/training_arrays.py", line 199, in fit_loop
#     outs = f(ins_batch)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py", line 2715, in __call__
#     return self._call(inputs)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py", line 2675, in _call
#     fetched = self._callable_fn(*array_vals)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/client/session.py", line 1472, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# ---------------------------------------------------------------------------

# %%
# Load the TensorBoard notebook extension.
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from datetime import datetime
import io
import itertools
from packaging import version
from six.moves import range

import tensorflow as tf
from tensorflow import keras

import matplotlib.pyplot as plt
import numpy as np
import sklearn.metrics

print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >= 2, \
    "This notebook requires TensorFlow 2.0 or above."
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# TensorFlow version:  1.15.0
# Traceback (most recent call last):
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-487-278e22cd3b09>", line 20, in <module>
#     "This notebook requires TensorFlow 2.0 or above."
# AssertionError: This notebook requires TensorFlow 2.0 or above.
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AssertionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/tensorflow/__init__.py", line 50, in __getattr__
#     module = self._load()
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/tensorflow/__init__.py", line 44, in _load
#     module = _importlib.import_module(self.__name__)
#   File "/Users/denisdunn/opt/anaconda3/lib/python3.7/importlib/__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1006, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 965, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'tensorflow_core.estimator'
# ---------------------------------------------------------------------------

# %%
import cv2,time
import numpy as np
print(cv2.__version__)
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# 4.1.2

# %%
/anaconda3/lib/python3.7/site-packages/cv2/data/haarcascade_frontalface_default.xml

# %%
face_cascade=cv2.CascadeClassifier('/anaconda3/lib/python3.7/site-packages/cv2/data/haarcascade_frontalface_default.xml')

# %%
face_cascade=cv2.CascadeClassifier('file:///Users/denisdunn/opt/anaconda3/lib/python3.7/site-packages/cv2/data/haarcascade_frontalface_default.xml')

# %%
face_cascade

# %%
gray=cv2.imread('/Users/denisdunn/Desktop/Ivb19_0881-319x319.png')

# %%
faces=face_cascade.detectMultiScale(gray,scaleFactor=1.05,minNeighbors=5)

# %%
print(faces)

# %%
for x,y,w,h, in faces:
    img = cv2.rectangle(gray, (x,y), (x+w,y+h),(0,255,0),3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-75790e98d3fd> in <module>
# ----> 1 for x,y,w,h, in faces:
#       2     img = cv2.rectangle(gray, (x,y), (x+w,y+h),(0,255,0),3)
#
# NameError: name 'faces' is not defined

# %%
cv2.imshow('gray',img)

# %%
#import cv2

#cvim2disp = cv2.imread('/Users/denisdunn/Desktop/Ivb19_0881-319x319.png')
cv2.imshow('img', img)
while(True):
    k = cv2.waitKey(33)
    if k == -1:  # if no key was pressed, -1 is returned
        continue
    else:
        break
cv2.destroyWindow('img')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-696d1c2ea2f1> in <module>
#       2
#       3 #cvim2disp = cv2.imread('/Users/denisdunn/Desktop/Ivb19_0881-319x319.png')
# ----> 4 cv2.imshow('img', img)
#       5 while(True):
#       6     k = cv2.waitKey(33)
#
# NameError: name 'img' is not defined

# %%
video=cv2.VideoCapture(0)
check,frame=video.read()
time.sleep(3) 
cv2.imshow('Capture',frame)
cv2.waitKey(0)
video.release()

# %%
pwd

# %%
cv2.destroyWindow('gray')

# %%
filename = '/Users/denisdunn/Desktop/shirt_test.png'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]

cv2.imshow('dst',img)
while(True):
    k = cv2.waitKey(33)
    if k == -1:  # if no key was pressed, -1 is returned
        continue
    else:
        break
cv2.destroyWindow('img')
#if cv2.waitKey(0) & 0xff == 27:
    #cv2.destroyAllWindows()

# %%
filename = '/Users/denisdunn/Desktop/shirt_test.png'
img = cv2.imread(filename)
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

gray = np.float32(gray)
dst = cv2.cornerHarris(gray,2,3,0.04)

#result is dilated for marking the corners, not important
dst = cv2.dilate(dst,None)

# Threshold for an optimal value, it may vary depending on the image.
img[dst>0.01*dst.max()]=[0,0,255]

cv2.imshow('dst',img)
cv2.waitKey()

cv2.destroyAllWindows()

# %%
from tensorflow.keras.models import Sequential

# %%
import keras
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-21-88d96843a926> in <module>
# ----> 1 import keras
#
# ModuleNotFoundError: No module named 'keras'

# %%
cv2.destroyAllWindows()

# %%
img = cv2.imread("image.jpg")
cv2.startWindowThread()
cv2.namedWindow("preview")
cv2.imshow("preview", im

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
from keras.preprocessing.image import save_img

# %%
img = load_img('/Users/denisdunn/Desktop/full_aerin/Aerin_Office_PhotoFrame_8x10.tif/Aerin_Office_PhotoFrame_8x10.tif')

# %%
img_array = img_to_array(img)

# %%
save_img('office_photoframe.jpg', img_array)

# %%
pwd
# Out:
# '/Users/denisdunn/estee_lauder'
