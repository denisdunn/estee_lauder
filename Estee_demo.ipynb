# %% [markdown]
# # ESTEE LAUDER IMAGE ANALYTICS POC

# %%
import tensorflow
from time import time
from tensorflow.keras import optimizers
from tensorflow.keras import layers
from tensorflow.keras.models import load_model
from tensorflow.keras import models
from tensorflow.keras import Sequential
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.applications.vgg16 import decode_predictions
from tensorflow.keras.applications.vgg16 import VGG16
# load an image from file
import sys
from numpy import load
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from matplotlib.image import imread
from numpy import expand_dims
from tensorflow.keras.applications.vgg16 import decode_predictions
import pickle
from tensorflow.keras.preprocessing.image import array_to_img

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from numpy import expand_dims
import numpy as np
import os
from PIL import Image
Image.MAX_IMAGE_PIXELS = None

# %%
IMG_SIZE=224
CATEGORIES=os.listdir(r'C:\Users\dedunn\Desktop\full_aerin')

# %%
len(CATEGORIES)
# Out:
# 44

# %%
#CATEGORIES=CATEGORIES[:3]+CATEGORIES[4:]

# %%
#model=load_model(r"C:\Users\dedunn\Desktop\weights-val_74-0.98.hdf5")

# %%
model = load_model(r"C:\Users\dedunn\Desktop\weights-improvement-264-0.97.hdf5")

# %%
def estee_lauder_image_path_predictor(img):   
    img1=load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE))
    y=img_to_array(img1)
    y=np.expand_dims(y, axis=0)
    y = preprocess_input(y)
    result=model.predict_classes(y)
    
    #features = model.predict(y)
    prediction=(r"C:\Users\dedunn\Desktop\full_aerin\{}\{}").format(str(CATEGORIES[int(result)]),str(CATEGORIES[int(result)]))
    return load_img(prediction)#print(CATEGORIES[int(result)])

# %%
def predicted_path(img):
    img1=load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE))
    y=img_to_array(img1)
    y=np.expand_dims(y, axis=0)
    y = preprocess_input(y)
    result=model.predict_classes(y)
    return print(CATEGORIES[int(result)])

# %% [markdown]
# # SCREEN SHOT OF IMAGES FOUND ON ESTEELAUDER.COM

# %% [markdown]
# # EXAMPLE OF TWO VERY SIMILAR IMAGES FOUND ON ESTEELAUDER.COM

# %%
img_path=r"C:\Users\dedunn\Desktop\full_aerin_test\F19_AERIN_AM_DIGITAL_3_SQUARE.jpg\Capture.JPG"
#img_path=r"C:\Users\dedunn\Desktop\full_aerin_test\F19_AERIN_AM_DIGITAL_4_SQUARE_v3.jpg\Capture.JPG"
load_img(img_path)

# %% [markdown]
# # MATCHED FILE PATH OF IMAGES LOCATED INSIDE OF THE DAM

# %%
estee_lauder_image_path_predictor(img_path)

# %%
predicted_path(img_path)

# %% [markdown]
# # CROPPED PICTURE EXAMPLE

# %%
img_path=r"C:\Users\dedunn\Desktop\full_aerin_test\FL17_AERIN_TLJ_TLS_HERO.jpg\Capture2.JPG"
load_img(img_path)

# %% [markdown]
# # MATCHED FILE PATH OF IMAGES LOCATED INSIDE OF THE DAM

# %%
estee_lauder_image_path_predictor(img_path)

# %%
predicted_path(img_path)

# %% [markdown]
# # EXAMPLES OF SUPERIMPOSED PHOTOS FOUND ON ESTEELAUDER.COM

# %%
#img_path=r"C:\Users\dedunn\Desktop\full_aerin_test\AERIN_MH_MOODBOARD_LR.jpg\Capture.JPG"
img_path=r"C:\Users\dedunn\Desktop\full_aerin_test\AERIN_IJ_MOODBOARD_LR.jpg\Capture.JPG"
load_img(img_path)

# %% [markdown]
# # MATCHED FILE PATH OF IMAGES LOCATED INSIDE OF THE DAM

# %%
estee_lauder_image_path_predictor(img_path)

# %%
predicted_path(img_path)

# %% [markdown]
# # EXAMPLE OF DETECTING AN IMAGE INSIDE OF AN IMAGE FROM ESTEELAUDER.COM

# %%
#img_path=r"C:\Users\dedunn\Desktop\full_aerin_test\AERIN_IJ_MOODBOARD_LR.jpg\Capture.JPG"
img_path=r"C:\Users\dedunn\Desktop\full_aerin_test\AERIN_IJ_50ML_SILO.jpg\Capture.JPG"
load_img(img_path)

# %% [markdown]
# # MATCHED FILE PATH OF IMAGES LOCATED INSIDE OF THE DAM

# %%
estee_lauder_image_path_predictor(img_path)

# %%
predicted_path(img_path)

# %%
"C:\Users\dedunn\Downloads\state.txt"

# %%
#img_path=r"C:\Users\dedunn\Desktop\full_aerin_test\F19_AERIN_LIM_DIGITAL_6.JPG\Capture.JPG"
